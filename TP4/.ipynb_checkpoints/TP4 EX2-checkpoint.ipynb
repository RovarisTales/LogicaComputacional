# %%
from pysmt.shortcuts import *
from pysmt.typing import *


def prove(f):
    with Solver(name="z3") as s:
        s.add_assertion(Not(f))
        if s.solve():
            print("Failed to prove.")
            #print(s.get_value(changed))
            print(s.get_value(seq))
            #print(s.get_value(aux))
            print("---------------------------")
        else:
            print("Proved.")
            
seq = (Symbol('seq'+'0',ArrayType(INT, INT)))

seq = Store(seq,Int(0),Int(99))

seq = Store(seq,Int(1),Int(99))

#print(banana)

#seq = banana

#seq = banana2

prove(Equals(seq,seq))
# Out:
# Proved.

# %% [markdown]
# ```python
# seq = [-2,1,2,-1,4,-4,-3,3]
# changed = True
# aux = 0
# while changed:
#     changed = False
#     for i in range(len(seq) - 1):
#         if seq[i] > seq[i+1]:
#             seq[i], seq[i+1] = seq[i+1], seq[i]
#             changed = True
#     aux += 1
# pass
#
#
# inv = changed == True
#
# inv =  True
#
# pos = forall j . 0 <= j < len(seq)-1 seq[j]<=seq[j+1]
# ```

# %% [markdown]
# seq = []
#
# for i in range(8):
#     seq.append(Symbol('seq'+str(i),INT))
# else:
#     seq.append(Symbol('changed',INT))
#
# if seq[i] > seq[i+1]:
#     seq[i], seq[i+1] = seq[i+1], seq[i]
#     changed = True
# else skip
#
# [assume seq[i]>seq[i+1]; seq[i+1],seq[i] = seq[i],seq[i+1];seq[9] = 1 || assume seq[i]<= seq[i+1];skip]
#
# [assume seq[i]>seq[i+1]; seq[i+1],seq[i] = seq[i],seq[i+1];seq[9] = 1; i=i+1] and [assume seq[i]<= seq[i+1]; i=i+1 ;skip]
#
#
# seq[i]>seq[i+1] -> [seq[i+1],seq[i] = seq[i],seq[i+1];seq[9] = 1; i=i+1] and seq[i]<= seq[i+1] -> [i = i + 1; skip]

# %% [markdown]
# seq = [-2,1,2,-1,4,-4,-3,3]
# changed = True
# cont = 0
# while changed:
#     changed = False
#     for i in range(len(seq) - 1):
#         if seq[i] > seq[i+1]:
#             seq[i], seq[i+1] = seq[i+1], seq[i]
#             changed = True
#     cont += 1
# print(seq,"\n",cont)

# %% [markdown]
# ```python
# pre = [assume changed==True and seq = [-2,1,2,-1,4,-4,-3,3]  ; assert inv ]
#      = changed == True and seq = [-2,1,2,-1,4,-4,-3,3] -> inv
#
# preser = [assume changed == True ; seq = trans();i = i+1; assert inv]
#       = changed == True -> [changed = False ,seq = trans();i = i+1; assert inv ]
#       = changed = True -> [seq = trans();i = i+1; assert  inv] [changed <- False ]
#       = changed = True -> [ i = i+1; assert  inv] [changed <- False ][seq <- trans()]
#       = changed = True -> [ assert  inv] [changed <- False ][seq <- trans()][ i <- i+1]
#
#
# pos = [ changed == False and inv ; skip ; assert pos ]
#
#
# #inv = ForAll([i],Implies(And(
#
# inv = ForAll([aux],Implies(And(aux>=Int(8)-i,aux>Int(8)-1),Select(seq[0],aux+Int(1)) >= Select(seq[0],aux)))
#
# pos = ForAll([k],Implies(And(k>=Int(0),k<Int(7)),Select(seq,k+Int(1)) >= Select(seq,k)))
#
# ```
# $$
# \begin{array}{l}
# [\,{\sf assume}\;\phi\; ;{{\sf assert}\; \theta\; ; \sf havoc }\;\vec{x} \; ; (\,({\sf assume }\; b \wedge \theta \; ; \; C \; ; {\sf assert}\;\theta \; ; {\sf assume}\; \mathit{False}) \: || \:
# {\sf assume}\; \neg b \wedge \theta \,)\; ; {\sf assert} \; \psi \,] \\ = \\
# \phi \to \theta \wedge \forall \vec{x}. \, (\,(b \wedge \theta \to [C\;; {\sf assert}\; \theta ]) \wedge (\neg b \wedge \theta \to \psi )\,)
# \end{array}
# $$

# %% [markdown]
# '''
# def init(seq,n):
#     for i in range(n):
#         x = [Int(-2),Int(1),Int(2),Int(-1),Int(4),Int(-4),Int(-3),Int(3),Int(1)]
#         seq = Store(seq,Int(i),x[i])
#     else:
#         seq = Store(seq,Int(8),Int(1))
#     return seq
#
#
# def trans(seq,n):
#     seq2 = (Symbol('seq'+'1',ArrayType(INT, INT)))
#     for i in range(n+1):
#         seq2 = Store(seq2,Int(i),Select(seq,Int(i)))
#     else:
#         seq2 = Store(seq2,Int(8),Int(1))
#     #print(seq2.serialize())
#     for i in range(n):
#         a = Ite(GT(Select(seq2,Int(i)),Select(seq2,Int(i)+Int(1))),
#             Select(seq2,Int(i)+Int(1)),
#             Select(seq2,Int(i)))
#         b = Ite(GT(Select(seq2,Int(i)),Select(seq2,Int(i)+Int(1))),
#             Select(seq2,Int(i)),
#             Select(seq2,Int(i)+1))
#         seq2 = Store(seq2,Int(i),a)
#         seq2 = Store(seq2,Int(i+1),b)
#
#         #s.add_assertion(Implies(a>b,Equals(changed,Int(1))))
#
#         #a = Select(seq2,Int(i))
#         #b = Select(seq2,Int(i)+1)
#
#         #And(Implies(a>b,And(substitute(seq[i],{seq[i]: b}),substitute(seq[i+1],{seq[i+1]: a}),substitute(seq[9],{seq[9]:Int(1)}))),
#         #   Implies(b>=a,))
#
#
#     #s.add_assertion(Equals(changed,Ite(Equals(seq,seq2),Int(0),Int(1))))
#     if s.is_sat(Equals(seq,seq2)):
#         print("iguais")
#         seq2 = Store(seq2,Int(8),Int(0))
#
#     return seq2
#
#
#
#
#
#
#
# #for i in range(10):
# #    print(Select(seq[4],Int(i)))
#
#
#
#     #print(seq[i+1].serialize())
#
#
# with Solver(name="z3") as s:
#
#     seq = (Symbol('seq'+'0',ArrayType(INT, INT)))
#
#     #seq = init(seq,8)
#
#
#     #k = Symbol('k',INT)
#
#     #i = Symbol('i',INT)
#
#     #aux = Symbol('aux',INT)
#
#     #changed = Symbol('changed',INT)
#
#     #cond = Equals(changed,Int(1))
#
#     #inv = TRUE()
#
#     #inv = ForAll([aux],Implies(And(aux>Int(7)-i,aux<=Int(7)),Select(seq,aux) >= Select(seq,aux-Int(1))))
#
#     #pos = ForAll([k],Implies(And(k>=Int(0),k<Int(7)),GE(Select(seq,k+Int(1)) , Select(seq,k))))
#
#     #pre = And(Equals(changed,Int(1)),Equals(seq,init(seq,8)))
#
#     #init = Implies(pre,TRUE())
#
#     #ciclo = Implies(And(inv,cond),Equals(seq,trans(seq,seq1,8,changed)))
#
#     #final = Implies(Not(cond),pos)
#
#     #print(inv)
#
#
#     while s.is_sat(Equals(Select(seq,Int(8)),Int(1))):
#         #print("oi")
#         seq = trans(seq,7)
#
#     pos = ForAll([k],Implies(And(k>=Int(0),k<Int(7)),Select(seq,k+Int(1)) >= Select(seq,k)))
#
#     #print(simplify(pos))
#     #prove(init)
#
#     #prove(ciclo)
#
#     #prove(final)
#     #pos = And(GE(Select(seq,Int(i)),Select(seq,Int(i+1)))for i in range(7))
#
#
#
#     if s.solve():
#         print("Provado")
#         print(s.get_value(seq))
#         #print(s.get_value(changed))
#
#     else:
#         print("nao Proved.")
#
# #[-2,1,2,-1,4,-4,-3,3]
# #[-2,1,-1,-1,4,-4,-3,3]
# '''

# %%
def init(seq,n):
    for i in range(n):
        x = [Int(-2),Int(1),Int(2),Int(-1),Int(4),Int(-4),Int(-3),Int(3),Int(1)]
        seq = Store(seq,Int(i),x[i])
    else:
        seq = Store(seq,Int(8),Int(1))
    return seq
    

def trans(seq,n):
    seq2 = (Symbol('seq'+'1',ArrayType(INT, INT)))
    for i in range(n+1):
        seq2 = Store(seq2,Int(i),Select(seq,Int(i)))
    else:
        seq2 = Store(seq2,Int(8),Int(1))
    #print(seq2.serialize())
    for i in range(n):
        a = Ite(GT(Select(seq2,Int(i)),Select(seq2,Int(i)+Int(1))),
            Select(seq2,Int(i)+Int(1)),
            Select(seq2,Int(i)))
        b = Ite(GT(Select(seq2,Int(i)),Select(seq2,Int(i)+Int(1))),
            Select(seq2,Int(i)),
            Select(seq2,Int(i)+1))
        seq2 = Store(seq2,Int(i),a)
        seq2 = Store(seq2,Int(i+1),b)
        
        #s.add_assertion(Implies(a>b,Equals(changed,Int(1))))
        
        #a = Select(seq2,Int(i))
        #b = Select(seq2,Int(i)+1)
        
        #And(Implies(a>b,And(substitute(seq[i],{seq[i]: b}),substitute(seq[i+1],{seq[i+1]: a}),substitute(seq[9],{seq[9]:Int(1)}))),
        #   Implies(b>=a,))
        
    
    #s.add_assertion(Equals(changed,Ite(Equals(seq,seq2),Int(0),Int(1))))
    
    seq2 = Store(seq2,Int(8),Ite(Equals(seq,seq2),Int(0),Int(1)))
    
    #if s.is_sat(Equals(seq,seq2)):
    #    print("iguais")
    #    seq2 = Store(seq2,Int(8),Int(0))
    
    return seq2

# %%
from pysmt.shortcuts import *
from pysmt.typing import *

# Auxiliares
def prime(v):
    return Symbol("next(%s)" % v.symbol_name(), v.symbol_type())
def fresh(v):
    return FreshSymbol(typename=v.symbol_type(),template=v.symbol_name()+"_%d")


class SAU(object):
    """Trivial representation of a while cycle and its unfolding."""
    def __init__(self, variables, pre , pos, control, trans, sname="z3"):
              
        self.variables = variables       # variables   
        self.pre = pre                   # pre-condition as a predicate in "variables"
        self.pos = pos                   # pos-condition as a predicate in "variables"
        self.control = control           # cycle control as a predicate in "variables"
        self.trans = trans               # cycle body as a binary transition relation 
                                         # in "variables" and "prime variables"
        
        self.prime_variables = [prime(v) for v in self.variables]
        self.frames = [And([Not(control),pos])]  
                 # inializa com uma só frame: a da terminação do ciclo
        
        self.solver = Solver(name=sname)

    def new_frame(self):        
        freshs = [fresh(v) for v in self.variables]    
        b = self.control
        S = self.trans.substitute(dict(zip(self.prime_variables,freshs)))
        W = self.frames[-1].substitute(dict(zip(self.variables,freshs)))
        
        self.frames.append(And([b , ForAll(freshs, Implies(S, W))]))
        
    def unfold(self,bound=0):
        n = 0
        while True:
            if n > bound:
                print("falha: número de tentativas ultrapassa o limite %d "%bound)
                break
            
            f = Or(self.frames)
            if self.solver.solve([self.pre,Not(f)]):  
                self.new_frame()
                n += 1
            else:
                print("sucesso na tentativa %d "%n)
                break

# %%
seq = (Symbol('seq'+'0',ArrayType(INT, INT)))
#N = Int(6)
#zero = Int(0)
#um   = Int(1)

# O ciclo
k  = Symbol("k",INT)
variables = [seq]

pre  =  Equals(seq,init(seq,8))     # pré-condição    
pos  =  ForAll([k],Implies(And(k>=Int(0),k<Int(7)),GE(Select(seq,k+Int(1)) , Select(seq,k))))  # pós-condição
cond =  Equals(Select(seq,Int(8)),Int(1))                # condição de controlo do ciclo
trans = Equals(prime(seq),trans(seq,7))     # corpo do ciclo como uma relaçao de transição

W = SAU(variables, pre, pos, cond, trans)

#Run
W.unfold(6)
# Out:
# ---------------------------------------------------------------------------
# PysmtValueError                           Traceback (most recent call last)
# Input In [5], in <cell line: 13>()
#      11 pos  =  ForAll([k],Implies(And(k>=Int(0),k<Int(7)),GE(Select(seq,k+Int(1)) , Select(seq,k))))  # pós-condição
#      12 cond =  Equals(Select(seq,Int(8)),Int(1))                # condição de controlo do ciclo
# ---> 13 trans = Equals(prime(seq),trans(seq,7))     # corpo do ciclo como uma relaçao de transição
#      15 W = SAU(variables, pre, pos, cond, trans)
#      17 #Run
#
# File ~/anaconda3/envs/logica/lib/python3.10/site-packages/pysmt/decorators.py:107, in assert_infix_enabled.<locals>.assert_infix_enabled_wrap(*args, **kwargs)
#     105 if not get_env().enable_infix_notation:
#     106     raise PysmtModeError(INFIX_ERROR_MSG)
# --> 107 return f(*args, **kwargs)
#
# File ~/anaconda3/envs/logica/lib/python3.10/site-packages/pysmt/fnode.py:969, in FNode.__call__(self, *args)
# ...

# %%
# Out:
# sucesso na tentativa 0
