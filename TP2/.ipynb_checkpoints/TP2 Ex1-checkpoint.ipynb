# %%
from pysmt.shortcuts import *
from pysmt.typing import INT
#import BitVector

a = 10 #resultado
b = 5 #
'''
#pc = 0
while y != 0: #pc = 1
    if y % 2: #pc = 2
        x = 2*x
        y = y/2
        if len(x) > n:
            #overflow
    else:     #pc = 3
        y = y-1
        z = z+x
#pc = 4
'''
def declare(i,n):
    state = {}
    state['pc'] = Symbol('pc'+str(i),INT)
    state['x'] = Symbol('x'+str(i),BVType(n))
    state['y'] = Symbol('y'+str(i),BVType(n))
    state['z'] = Symbol('z'+str(i),INT)
    return state



def init(state,a,b,n):
    
    return And(Equals(state['x'],BV(a,n)),
               Equals(state['y'],BV(b,n)),
               Equals(state['z'],Int(0)),
               Equals(state['pc'],Int(0)))

def trans(curr,prox,bv2,n):
    t0 = And(Equals(curr['pc'],Int(0)),
             Equals(prox['pc'],Int(1)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z'])) 
    
    t1 = And(Equals(curr['pc'],Int(1)),
             Equals(BVURem(curr['y'],bv2),BVZero(n)),
             Equals(prox['pc'],Int(2)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z']))
    
    t2 = And(Equals(curr['pc'],Int(2)),
             Equals(prox['pc'],Int(1)),
             BVUGE(prox['x'],BVMul(curr['x'],bv2)),
             Equals(BVMul(curr['x'],bv2),prox['x']),
             Equals(BVUDiv(curr['y'],bv2),prox['y']),
             Equals(curr['z'],prox['z']))
    
    te = And(Equals(curr['pc'],Int(2)),
             Equals(prox['pc'],Int(5)),

             BVUGE(BVMul(curr['x'],bv2),prox['x']),
             Equals(BVUDiv(curr['y'],bv2),prox['y']),
             Equals(curr['z'],prox['z']))
    
    te2 = And(Equals(curr['pc'],Int(5)),
             Equals(prox['pc'],Int(5)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z']))
    
    t3 = And(Equals(curr['pc'],Int(1)),
             Equals(BVURem(curr['y'],bv2),BVOne(n)),
             Equals(prox['pc'],Int(3)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z']))
    
    t4 = And(Equals(curr['pc'],Int(3)),
             Equals(prox['pc'],Int(1)),
             Equals(curr['x'],prox['x']),
             Equals(BVSub(curr['y'],BVOne(n)),prox['y']),
             Equals(curr['z']+BVToNatural(curr['x']),prox['z']))
    
    t5 = And(Equals(curr['pc'],Int(1)),
             Equals(prox['pc'],Int(4)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z']),
             Equals(curr['y'],BVZero(n)))
    
    t6 = And(Equals(curr['pc'],Int(4)),
             Equals(prox['pc'],Int(4)),
             Equals(curr['x'],prox['x']),
             Equals(curr['y'],prox['y']),
             Equals(curr['z'],prox['z']))
    
    return Or(t1,t2,t3,t0,t4,t5,t6)




def gera_traco(declare,init,trans,a,b,n,k):

    with Solver(name="z3") as s:
        
        bv2 = BV(2,n)
        
        trace = [declare(i,n) for i in range(k)]
        
        s.add_assertion(init(trace[0],a,b,n))
        
        for i in range(k-1):
            s.add_assertion(trans(trace[i],trace[i+1],bv2,n))
        
        if s.solve():
            for i in range(k):
                print("Passo", i)
                for v in trace[i]:
                    print(v,"=",s.get_value(trace[i][v]))

gera_traco(declare,init,trans,5,8,6,40)
# Out:
# Passo 0
# pc = 0
# x = 5_6
# y = 8_6
# z = 0
# Passo 1
# pc = 1
# x = 5_6
# y = 8_6
# z = 0
# Passo 2
# pc = 2
# x = 5_6
# y = 8_6
# z = 0
# Passo 3
# pc = 1
# x = 10_6
# y = 4_6
# z = 0
# Passo 4
# pc = 2
# x = 10_6
# y = 4_6
# z = 0
# Passo 5
# pc = 1
# x = 20_6
# y = 2_6
# z = 0
# Passo 6
# pc = 2
# x = 20_6
# y = 2_6
# z = 0
# Passo 7
# pc = 1
# x = 40_6
# y = 1_6
# z = 0
# Passo 8
# pc = 3
# x = 40_6
# y = 1_6
# z = 0
# Passo 9
# pc = 1
# x = 40_6
# y = 0_6
# z = 40
# Passo 10
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 11
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 12
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 13
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 14
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 15
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 16
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 17
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 18
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 19
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 20
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 21
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 22
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 23
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 24
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 25
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 26
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 27
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 28
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 29
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 30
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 31
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 32
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 33
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 34
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 35
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 36
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 37
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 38
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
# Passo 39
# pc = 4
# x = 40_6
# y = 0_6
# z = 40
