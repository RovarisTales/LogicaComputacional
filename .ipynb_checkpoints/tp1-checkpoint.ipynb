# %%
from ortools.linear_solver import pywraplp
from random import randrange,choice
horario = pywraplp.Solver.CreateSolver('SCIP')

S,T,P,C = 5,20,10,100
disp = []
h= [0,1,1,1]
for c in range(C):
    disp.append([])
    for t in range(T):
        disp[c].append(choice(h))
#print(disp)
#A disponibilidade de cada participante, incluindo o lider. Essa disponibilidade   é um conjunto de “slots” 
#representada numa matriz booleana de acessibilidade com uma linha por cada participante 1..C e 
#uma coluna por “slot” 1..T
#disp [C][T] = []

#O conjunto de colaboradores de cada projeto, o seu líder e o número mínimo  de reuniões semanais.
#Nesse caso para um projeto de 0 - P , está associado os colaboradores 
# ((1,2,0),1,3),((4,3,2),4,3),((4,5,6,7,8,9),6,2),((1,8,9,10,11,12,13,14),11,2),((13,15,16,17,18,19),13,2)
proj = [] 
lideres = []
for p in range(P):
    colab = set()
    for col in range(14):
        colab.add(randrange(C))
    cola = list(colab)
    l = random.choice(cola)
    lideres.append(l)
    hora = randrange(1,5)
    proj.append((cola,l,hora))
    

print(proj)




x = {}
for s in range(S):
    x[s]= {}
    for t in range(T):
        x[s][t] = {}
        for p in range(P):
            x[s][t][p] = {}
            for c in range(C):
                x[s][t][p][c] = horario.BoolVar(f'x[{s},{t},{p},{c}]')

def X(s,t,p,c):              # abreviatura
    return x[s][t][p][c] 
#print(round(len(proj[0][0])/2))

#Adiciona condições para que se um colaborador não esteja disponivel para certo slot
#ele não posso ser alocada a esse spot
for c in range(C):
    for t in range(T):
        if disp[c][t] == 0:
            for p in range(P):
                for s in range(S):
                    horario.Add((X(s,t,p,c))== 0 )

#cada colaborador nao pode participar de um projeto que nao é seu
for c in range(C):
    for p in range(P):
        if c not in proj[p][0]:
            for s in range(S):
                for t in range(T):
                    horario.Add((X(s,t,p,c))== 0)   


            

#checa se o mesmo colaborador esta fazendo o trabalho em 2 projetos diferentes ao mesmo tempo
for c in range(C):
    for t in range(T):
        horario.Add(sum(X(s,t,p,c) for p in range(P) for s in range(S))<= 1 )

#Adiciona condições para que se o lider não esteja disponivel não aconteça o projeto   
for p in range(P):
    l = proj[p][1]
    for d in disp[l]:
        if d == 0:
            for s in range(S):
                for c in proj[p][0]:
                    horario.Add((X(s,t,p,c))== 0 )
    
# Cada sala não pode ter mais que uma reunião ao mesmo tempo
for s in range(S):
    for t in range(T):
        horario.Add(sum(X(s,t,p,c) for p in range(P) for c in lideres) <= 1)
#Adiciona condições para que pelo menos 50% dos colaboradores de um dado projeto esteja presente em um slot 
#alocado a este projeto
for p in range(P):
    for t in range(T):
        for s in range(S):
            horario.Add(sum(X(s,t,p,c) for c in proj[p][0])  >= (X(s,t,p,proj[p][1])*round(len(proj[p][0])/2)))
     
    
#Adiciona condições para que o número de reunioes por projeto seja maior que o minimo definido
for p in range(P):
    horario.Add ( proj[p][2] <= sum(X(s,t,p,lideres[p]) for s in range (S) for t in range(T)))

    
for p in range(P):
    for s in range(S):
        for t in range(T):
            horario.Minimize(sum(X(s,t,p,c) for c in range(C)))
    

    
    
    
    
h = sum(X(s,t,p,proj[p][1])for s in range(S) for t in range(T) for p in range(P))


horario.Maximize(h)


status = horario.Solve()
print(status)
if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
    
    #for p in range(P):
    #    for t in range(T):
    #        for s in range(S):
    #            for c in range(C):
    #                print(X(s,t,p,c).solution_value())
    for s in range(S):
        print("Sala ", s, ":")
        for t in range(T):
            for p in range(P):
                if X(s,t,p,proj[p][1]).solution_value() == 1:
                   
                    a = []
                    for c in proj[p][0] :
                        if X(s,t,p,c).solution_value() == True:
                            a.append(c)
                    print("Slot ", t ," Projeto:", p," Colaboradores:", a )
# Out:
# [([32, 2, 99, 4, 68, 35, 74, 14, 18, 52, 87, 88, 58, 29], 87, 3), ([65, 98, 66, 1, 72, 41, 74, 43, 44, 76, 79, 83, 59, 61], 59, 2), ([32, 97, 34, 35, 68, 40, 10, 11, 76, 46, 78, 80, 90], 76, 2), ([32, 67, 36, 5, 35, 8, 44, 77, 12, 54, 87, 56, 29], 54, 4), ([5, 6, 38, 74, 11, 14, 79, 81, 51, 19, 88, 27, 92, 61], 79, 3), ([96, 97, 99, 38, 8, 76, 13, 78, 77, 55, 24, 90, 63], 77, 3), ([96, 97, 32, 6, 39, 76, 15, 56, 62, 30, 57], 57, 2), ([33, 3, 41, 45, 48, 80, 50, 18, 53, 56, 57, 90, 28], 80, 4), ([0, 66, 67, 6, 43, 17, 49, 87, 55, 22, 56, 28, 29, 94], 94, 1), ([98, 67, 39, 91, 75, 11, 49, 83, 20, 85, 56, 26, 59], 20, 4)]
# 0
# Sala  0 :
# Slot  0  Projeto: 8  Colaboradores: [0, 66, 43, 49, 22, 28, 94]
# Slot  1  Projeto: 3  Colaboradores: [36, 35, 8, 12, 54, 56]
# Slot  2  Projeto: 6  Colaboradores: [96, 6, 15, 56, 62, 57]
# Slot  3  Projeto: 1  Colaboradores: [65, 98, 1, 74, 44, 59, 61]
# Slot  4  Projeto: 2  Colaboradores: [34, 68, 10, 11, 76, 90]
# Slot  5  Projeto: 5  Colaboradores: [8, 77, 55, 24, 90, 63]
# Slot  6  Projeto: 3  Colaboradores: [32, 67, 5, 12, 54, 29]
# Slot  7  Projeto: 0  Colaboradores: [2, 99, 68, 14, 18, 52, 87]
# Slot  8  Projeto: 9  Colaboradores: [98, 75, 11, 49, 83, 20, 85, 26]
# Slot  9  Projeto: 7  Colaboradores: [33, 3, 41, 45, 48, 80, 50, 56]
# Slot  10  Projeto: 3  Colaboradores: [35, 8, 44, 12, 54, 29]
# Slot  11  Projeto: 8  Colaboradores: [0, 6, 17, 55, 22, 29, 94]
# Slot  12  Projeto: 1  Colaboradores: [65, 98, 1, 74, 44, 59, 61]
# Slot  13  Projeto: 5  Colaboradores: [97, 99, 38, 13, 77, 63]
# Slot  14  Projeto: 4  Colaboradores: [5, 6, 74, 14, 79, 51, 19, 88, 61]
# Slot  15  Projeto: 7  Colaboradores: [33, 41, 80, 50, 18, 28]
# Slot  16  Projeto: 5  Colaboradores: [38, 13, 78, 77, 55, 63]
# Slot  17  Projeto: 3  Colaboradores: [32, 36, 5, 8, 54, 29]
# Slot  18  Projeto: 3  Colaboradores: [32, 67, 5, 35, 54, 29]
# Sala  1 :
# Slot  0  Projeto: 1  Colaboradores: [65, 1, 72, 74, 44, 59, 61]
# Slot  1  Projeto: 9  Colaboradores: [67, 11, 49, 83, 20, 85]
# Slot  2  Projeto: 2  Colaboradores: [35, 68, 40, 10, 76, 78]
# Slot  3  Projeto: 5  Colaboradores: [96, 99, 38, 13, 77, 24, 90, 63]
# Slot  4  Projeto: 9  Colaboradores: [91, 75, 20, 85, 56, 26]
# Slot  5  Projeto: 6  Colaboradores: [97, 39, 56, 62, 30, 57]
# Slot  6  Projeto: 4  Colaboradores: [38, 79, 81, 51, 19, 27, 92]
# Slot  7  Projeto: 5  Colaboradores: [8, 78, 77, 24, 90, 63]
# Slot  8  Projeto: 8  Colaboradores: [0, 66, 6, 43, 22, 28, 94]
# Slot  9  Projeto: 2  Colaboradores: [35, 68, 10, 11, 76, 90]
# Slot  10  Projeto: 9  Colaboradores: [98, 75, 49, 20, 85, 26]
# Slot  11  Projeto: 4  Colaboradores: [14, 79, 51, 19, 88, 27, 61]
# Slot  12  Projeto: 0  Colaboradores: [32, 4, 68, 35, 52, 87, 58]
# Slot  13  Projeto: 3  Colaboradores: [32, 5, 35, 12, 54, 56]
# Slot  14  Projeto: 7  Colaboradores: [33, 41, 45, 48, 80, 56]
# Slot  15  Projeto: 8  Colaboradores: [0, 6, 17, 49, 22, 56, 94]
# Slot  16  Projeto: 6  Colaboradores: [96, 97, 56, 62, 30, 57]
# Slot  17  Projeto: 4  Colaboradores: [38, 79, 81, 51, 19, 88, 27, 92]
# Slot  18  Projeto: 7  Colaboradores: [33, 45, 80, 18, 90, 28]
# Sala  2 :
# Slot  0  Projeto: 9  Colaboradores: [98, 75, 11, 83, 20, 26]
# Slot  1  Projeto: 5  Colaboradores: [97, 99, 77, 24, 90, 63]
# Slot  2  Projeto: 9  Colaboradores: [39, 49, 83, 20, 85, 26]
# Slot  3  Projeto: 2  Colaboradores: [32, 97, 34, 35, 11, 76]
# Slot  4  Projeto: 5  Colaboradores: [38, 8, 78, 77, 55, 63]
# Slot  5  Projeto: 1  Colaboradores: [65, 66, 1, 74, 44, 59, 61]
# Slot  6  Projeto: 1  Colaboradores: [66, 1, 72, 74, 43, 59, 61]
# Slot  7  Projeto: 4  Colaboradores: [5, 6, 11, 79, 81, 51, 92]
# Slot  8  Projeto: 5  Colaboradores: [96, 97, 38, 13, 77, 55]
# Slot  9  Projeto: 9  Colaboradores: [39, 75, 83, 20, 85, 26]
# Slot  10  Projeto: 0  Colaboradores: [2, 4, 74, 18, 52, 87, 58]
# Slot  11  Projeto: 2  Colaboradores: [35, 68, 40, 10, 76, 78]
# Slot  12  Projeto: 4  Colaboradores: [5, 11, 79, 81, 88, 27, 92]
# Slot  13  Projeto: 7  Colaboradores: [33, 45, 48, 80, 18, 53]
# Slot  14  Projeto: 2  Colaboradores: [32, 35, 68, 40, 10, 76, 46]
# Slot  15  Projeto: 5  Colaboradores: [96, 38, 13, 77, 24, 63]
# Slot  16  Projeto: 3  Colaboradores: [36, 35, 8, 44, 54, 29]
# Slot  17  Projeto: 9  Colaboradores: [49, 83, 20, 85, 56, 26]
# Slot  18  Projeto: 9  Colaboradores: [98, 39, 49, 83, 20, 85]
# Sala  3 :
# Slot  0  Projeto: 7  Colaboradores: [33, 3, 48, 80, 18, 53]
# Slot  1  Projeto: 6  Colaboradores: [96, 6, 39, 62, 30, 57]
# Slot  2  Projeto: 0  Colaboradores: [99, 4, 14, 87, 88, 58, 29]
# Slot  3  Projeto: 9  Colaboradores: [39, 91, 75, 49, 20, 85]
# Slot  4  Projeto: 6  Colaboradores: [96, 32, 6, 39, 62, 57]
# Slot  5  Projeto: 7  Colaboradores: [33, 3, 80, 50, 18, 28]
# Slot  6  Projeto: 5  Colaboradores: [96, 99, 13, 78, 77, 55]
# Slot  7  Projeto: 1  Colaboradores: [65, 66, 43, 44, 83, 59, 61]
# Slot  8  Projeto: 0  Colaboradores: [32, 2, 4, 35, 18, 87, 58]
# Slot  9  Projeto: 0  Colaboradores: [2, 4, 18, 52, 87, 58, 29]
# Slot  10  Projeto: 8  Colaboradores: [0, 6, 43, 17, 55, 28, 94]
# Slot  11  Projeto: 3  Colaboradores: [32, 36, 5, 44, 54, 56]
# Slot  12  Projeto: 5  Colaboradores: [99, 38, 8, 13, 77, 24]
# Slot  13  Projeto: 8  Colaboradores: [0, 67, 6, 43, 17, 28, 94]
# Slot  14  Projeto: 9  Colaboradores: [67, 39, 91, 11, 20, 85]
# Slot  15  Projeto: 9  Colaboradores: [39, 91, 75, 83, 20, 26]
# Slot  16  Projeto: 0  Colaboradores: [2, 4, 68, 14, 18, 87, 88]
# Slot  17  Projeto: 8  Colaboradores: [0, 43, 17, 55, 22, 28, 94]
# Slot  18  Projeto: 5  Colaboradores: [97, 99, 13, 77, 55, 63]
# Sala  4 :
# Slot  0  Projeto: 3  Colaboradores: [32, 36, 5, 35, 8, 54]
# Slot  1  Projeto: 7  Colaboradores: [3, 41, 48, 80, 18, 28]
# Slot  2  Projeto: 7  Colaboradores: [33, 3, 41, 48, 80, 50, 53, 28]
# Slot  3  Projeto: 3  Colaboradores: [36, 5, 8, 54, 56, 29]
# Slot  4  Projeto: 0  Colaboradores: [4, 14, 52, 87, 88, 58, 29]
# Slot  5  Projeto: 8  Colaboradores: [0, 6, 43, 17, 22, 29, 94]
# Slot  6  Projeto: 7  Colaboradores: [33, 3, 80, 18, 53, 28]
# Slot  7  Projeto: 6  Colaboradores: [96, 97, 56, 62, 30, 57]
# Slot  8  Projeto: 3  Colaboradores: [67, 36, 8, 44, 54, 56]
# Slot  9  Projeto: 1  Colaboradores: [65, 98, 1, 72, 43, 44, 59]
# Slot  10  Projeto: 4  Colaboradores: [79, 81, 51, 19, 88, 27, 92]
# Slot  11  Projeto: 7  Colaboradores: [41, 48, 80, 50, 53, 28]
# Slot  12  Projeto: 8  Colaboradores: [0, 6, 43, 17, 49, 29, 94]
# Slot  13  Projeto: 9  Colaboradores: [39, 91, 75, 49, 20, 26]
# Slot  14  Projeto: 5  Colaboradores: [96, 97, 38, 77, 55, 90]
# Slot  15  Projeto: 3  Colaboradores: [32, 67, 36, 35, 54, 29]
# Slot  16  Projeto: 8  Colaboradores: [66, 67, 43, 17, 49, 22, 94]
# Slot  17  Projeto: 0  Colaboradores: [99, 4, 68, 74, 18, 52, 87]
# Slot  18  Projeto: 4  Colaboradores: [6, 14, 79, 81, 88, 92, 61]
